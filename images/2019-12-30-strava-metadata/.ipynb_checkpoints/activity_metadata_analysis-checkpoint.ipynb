# %%
import pandas as pd

# %%
df = pd.read_csv("activities.csv")
df.head()
# Out:
#    Activity ID              Activity Date             Activity Name  \
# 0      1451703  Aug 31, 2011, 10:02:38 PM                        WW
# 1      1451757   Aug 3, 2011, 10:08:09 PM             08/03/2011 WW
# 2      1451762   Aug 24, 2011, 9:57:56 PM             08/24/2011 WW
# 3      1451904    Jun 4, 2011, 2:06:12 PM  06/04/2011 Lexington, VA
# 4      1451907   Jun 1, 2011, 10:06:07 PM             06/01/2011 WW
#
#   Activity Type                Activity Description  Elapsed Time Distance  \
# 0          Ride  Hard ride, flatted on the way back          6885    50.37
# 1          Ride                       WW Tabor Loop          5954    49.15
# 2          Ride                                 NaN          6283    48.00
# 3          Ride                                 NaN         19817   125.90
# 4          Ride                                 NaN          5604    50.07
#
#    Relative Effort Commute Activity Gear                   Filename
# ...

# %%
df.dtypes
# Out:
# Activity ID               int64
# Activity Date            object
# Activity Name            object
# Activity Type            object
# Activity Description     object
# Elapsed Time              int64
# Distance                 object
# Relative Effort         float64
# Commute                  object
# Activity Gear            object
# Filename                 object
# dtype: object

# %%
df.Distance = df.Distance.str.replace(',','').astype('float')

# %%
df.loc[df["Activity Name"].str.contains("#olson"), :].head()
# Out:
#       Activity ID              Activity Date  \
# 3076   1243240041  Oct 23, 2017, 11:16:22 AM
# 3118   1263171098    Nov 5, 2017, 7:57:05 PM
# 3124   1265053391   Nov 7, 2017, 11:57:42 AM
# 3128   1267924233   Nov 9, 2017, 12:56:43 PM
# 3183   1299507026    Dec 2, 2017, 8:06:57 PM
#
#                                           Activity Name Activity Type  \
# 3076                   Baby's first 5k #stroller #olson           Run
# 3118  Stroller jam: racing home when be wakes up! 7l...           Run
# 3124  Wim Hof (shorts only) morning, with bebe! #str...           Run
# 3128  Cold one for the baby. Shirtless for me, felt ...           Run
# 3183                    Team adventure #stroller #olson           Run
#
#      Activity Description  Elapsed Time  Distance  Relative Effort Commute  \
# 3076                  NaN          1678      4.94              NaN   False
# 3118                  NaN          2764      9.28              NaN   False
# ...

# %%
df.loc[df["Activity Name"].str.contains("#stroller"), :].head()
# Out:
#       Activity ID              Activity Date  \
# 3076   1243240041  Oct 23, 2017, 11:16:22 AM
# 3118   1263171098    Nov 5, 2017, 7:57:05 PM
# 3124   1265053391   Nov 7, 2017, 11:57:42 AM
# 3128   1267924233   Nov 9, 2017, 12:56:43 PM
# 3183   1299507026    Dec 2, 2017, 8:06:57 PM
#
#                                           Activity Name Activity Type  \
# 3076                   Baby's first 5k #stroller #olson           Run
# 3118  Stroller jam: racing home when be wakes up! 7l...           Run
# 3124  Wim Hof (shorts only) morning, with bebe! #str...           Run
# 3128  Cold one for the baby. Shirtless for me, felt ...           Run
# 3183                    Team adventure #stroller #olson           Run
#
#      Activity Description  Elapsed Time  Distance  Relative Effort Commute  \
# 3076                  NaN          1678      4.94              NaN   False
# 3118                  NaN          2764      9.28              NaN   False
# ...

# %%
df.loc[df["Activity Name"].str.contains("#olson"), :].Distance.sum()
# Out:
# 1353.86

# %%
df.loc[df["Activity Name"].str.contains("#stroller"), :].Distance.sum()
# Out:
# 1379.35

# %%
df.loc[df["Activity Name"].str.contains("#olson") & ~df["Activity Name"].str.contains("#stroller"), :]
# Out:
# Empty DataFrame
# Columns: [Activity ID, Activity Date, Activity Name, Activity Type, Activity Description, Elapsed Time, Distance, Relative Effort, Commute, Activity Gear, Filename]
# Index: []

# %%
df.loc[df["Activity Name"].str.contains("#stoller"), :]
# Out:
# Empty DataFrame
# Columns: [Activity ID, Activity Date, Activity Name, Activity Type, Activity Description, Elapsed Time, Distance, Relative Effort, Commute, Activity Gear, Filename]
# Index: []

# %%
df.loc[~df["Activity Name"].str.contains("#olson") & df["Activity Name"].str.contains("#stroller"), :]
# Out:
#       Activity ID             Activity Date  \
# 4772   2621521254  Aug 15, 2019, 3:13:42 PM
# 4936   2819160968  Oct 26, 2019, 5:04:08 PM
#
#                                           Activity Name Activity Type  \
# 4772         Abel's first stroller run! #abel #stroller           Run
# 4936  #Olson, Kim and I doing laps on the very quiet...           Run
#
#                                    Activity Description  Elapsed Time  \
# 4772                                                NaN          1604
# 4936  A very low traffic road, our little stroller r...          6615
#
#       Distance  Relative Effort Commute Activity Gear  \
# 4772      5.06             30.0   False           NaN
# 4936     20.43              NaN   False           NaN
#
#                           Filename
# 4772  activities/2781062024.fit.gz
# 4936  activities/2987666843.fit.gz

# %%
df.loc[df["Activity Type"].str.contains("Run") & df["Activity Name"].str.contains("#stroller"), :].head()
# Out:
#       Activity ID              Activity Date  \
# 3076   1243240041  Oct 23, 2017, 11:16:22 AM
# 3118   1263171098    Nov 5, 2017, 7:57:05 PM
# 3124   1265053391   Nov 7, 2017, 11:57:42 AM
# 3128   1267924233   Nov 9, 2017, 12:56:43 PM
# 3183   1299507026    Dec 2, 2017, 8:06:57 PM
#
#                                           Activity Name Activity Type  \
# 3076                   Baby's first 5k #stroller #olson           Run
# 3118  Stroller jam: racing home when be wakes up! 7l...           Run
# 3124  Wim Hof (shorts only) morning, with bebe! #str...           Run
# 3128  Cold one for the baby. Shirtless for me, felt ...           Run
# 3183                    Team adventure #stroller #olson           Run
#
#      Activity Description  Elapsed Time  Distance  Relative Effort Commute  \
# 3076                  NaN          1678      4.94              NaN   False
# 3118                  NaN          2764      9.28              NaN   False
# ...

# %%
df.loc[df["Activity Type"].str.contains("Run") & df["Activity Name"].str.contains("#stroller"), :].Distance.sum()
# Out:
# 1357.62

# %%
df.loc[df["Activity Name"].str.contains("#stroller"), :].Distance.sum()/1.609
# Out:
# 857.2715972653822

# %%
run = df["Activity Type"].str.contains("Run")
stroller = df["Activity Name"].str.contains("#stroller")
miles = (df
    .loc[run & stroller, :]  # filter
    .loc[:, 'Distance']  # select
    .astype('float')  # convert dtype
    .sum()/1.609  # sum and convert to miles
)
miles
# Out:
# 843.7663144810441
